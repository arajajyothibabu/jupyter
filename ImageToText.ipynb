# %%
from PIL import Image
from pytesseract import image_to_string
from autocorrect import spell

text = image_to_string(Image.open('text-images/USAhF7041.png'), lang='eng')
print(text)

for t in text.split(" "):
    print spell(t)
# Out:
# PAGE 7O41
#
# faa gently ahaok hia head, which. ae aomenfrat ounk into hio beard. a nario, olaip of desert olretched
# wealward Before fim ao fax ae the eye, could reach, dividing bya. fovels, of water. alone thio natural. ayke
# fox him te each i, feo los, ia the paiaon. fe command any MED, and xae securely grated with ion.
# then he examined the walle, but not a atone waa foore. aa he did a0, hia eye fell upon the floor, and he
# nokiced thal tao of the atonea that fay about had Been caised up by aome one and a third faid upon
# are of no avail oo fong aa art and fife are not one and the same ao fong aa act ia not the alpha and
# omega of existence, bul merely an amusement ov a decoration. agqne had been tue to herself, and had
# modeathy but: oteadfaatly. declared that ahe coufa not. possibly enter the temple of iaia, and fer aefusal
# Baad boon accepled quite calmby, ano wvithout any aaqument OL conkaoveray. ohe had not. been able to
# ...
